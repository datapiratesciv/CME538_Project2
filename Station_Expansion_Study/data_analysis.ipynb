# %%
# Import 3rd party libraries
import os
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')

# %%
trips_data = pd.read_csv('trips_data.csv')
weather_data = pd.read_csv('weather_data.csv')
stations = pd.read_csv('stations.csv')

# %%
trips_data.head()
# Out:
#     Trip Id  Trip Duration  Start Station Id                 Start Time  \
# 0  712441.0            274            7006.0  2017-01-01 00:03:00-05:00
# 1  712442.0            538            7046.0  2017-01-01 00:03:00-05:00
# 2  712443.0            992            7048.0  2017-01-01 00:05:00-05:00
# 3  712444.0           1005            7177.0  2017-01-01 00:09:00-05:00
# 4  712445.0            645            7203.0  2017-01-01 00:14:00-05:00
#
#                           Start Station Name  End Station Id  \
# 0            Bay St / College St (East Side)          7021.0
# 1                 Niagara St / Richmond St W          7147.0
# 2  Front St / Yonge St (Hockey Hall of Fame)          7089.0
# 3            East Liberty St / Pirandello St          7202.0
# 4                Bathurst St / Queens Quay W          7010.0
#
#                     End Time                  End Station Name User Type
# 0  2017-01-01 00:08:00-05:00                Bay St / Albert St    Member
# 1  2017-01-01 00:12:00-05:00            King St W / Fraser Ave    Member
# 2  2017-01-01 00:22:00-05:00              Church St  / Wood St    Member
# 3  2017-01-01 00:26:00-05:00  Queen St W / York St (City Hall)    Member
# 4  2017-01-01 00:25:00-05:00           King St W / Spadina Ave    Member

# %%
weather_data.head()
# Out:
#    ï»¿"Longitude (x)"  Latitude (y)         Station Name  Climate ID  \
# 0               -79.4         43.63  TORONTO CITY CENTRE     6158359
# 1               -79.4         43.63  TORONTO CITY CENTRE     6158359
# 2               -79.4         43.63  TORONTO CITY CENTRE     6158359
# 3               -79.4         43.63  TORONTO CITY CENTRE     6158359
# 4               -79.4         43.63  TORONTO CITY CENTRE     6158359
#
#           Date/Time  Year  Month  Day   Time  Temp (Â°C)  ...  Wind Spd Flag  \
# 0  2017-01-01 00:00  2017      1    1  00:00         1.5  ...            NaN
# 1  2017-01-01 01:00  2017      1    1  01:00         1.5  ...            NaN
# 2  2017-01-01 02:00  2017      1    1  02:00         1.0  ...            NaN
# 3  2017-01-01 03:00  2017      1    1  03:00         1.2  ...            NaN
# 4  2017-01-01 04:00  2017      1    1  04:00         1.3  ...            NaN
#
#    Visibility (km)  Visibility Flag  Stn Press (kPa)  Stn Press Flag  Hmdx  \
# 0             16.1              NaN            99.81             NaN   NaN
# 1             16.1              NaN           100.01             NaN   NaN
# 2             16.1              NaN           100.14             NaN   NaN
# 3             16.1              NaN           100.32             NaN   NaN
# 4             16.1              NaN           100.48             NaN   NaN
#
#   Hmdx Flag  Wind Chill  Wind Chill Flag  Weather
# 0       NaN         NaN              NaN      NaN
# 1       NaN         NaN              NaN      NaN
# 2       NaN         NaN              NaN      NaN
# 3       NaN         NaN              NaN      NaN
# 4       NaN         NaN              NaN      NaN
#
# [5 rows x 28 columns]

# %%
stations.head()
# Out:
#    station_id                          name        lat        lon
# 0        7000  Fort York  Blvd / Capreol Ct  43.639832 -79.395954
# 1        7001     Wellesley Station Green P  43.664964 -79.383550
# 2        7002    St. George St / Bloor St W  43.667333 -79.399429
# 3        7003      Madison Ave / Bloor St W  43.667158 -79.402761
# 4        7004       University Ave / Elm St  43.656518 -79.389099
